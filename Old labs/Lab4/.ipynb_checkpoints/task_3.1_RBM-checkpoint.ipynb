# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neural_network import BernoulliRBM
from sklearn import metrics
from sklearn.metrics import mean_squared_error

# %%
X_train = pd.read_csv("MNIST_data/bindigit_trn.csv",header=None,dtype=np.float32).as_matrix()
y_train = pd.read_csv("MNIST_data/targetdigit_trn.csv",header=None,names=["Label"],dtype=np.float32).as_matrix()

X_test = pd.read_csv("MNIST_data/bindigit_tst.csv",header=None,dtype=np.float32).as_matrix()
y_test = pd.read_csv("MNIST_data/targetdigit_tst.csv",header=None,names=["Label"],dtype=np.float32).as_matrix()

# %%
y_train
# Out:
# array([[ 6.],
#        [ 6.],
#        [ 1.],
#        ...,
#        [ 5.],
#        [ 6.],
#        [ 5.]], dtype=float32)

# %%
#Helper class for plotting images
def plotImage(images,predictions):
    n = 10  # how many digits we will display
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(images[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(predictions[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
def plotWeights(weights):
    n = weights.shape[0]  # how many digits we will display
    plt.figure(figsize=(20, 20))
    for i in range(n):
        # display weights
        ax = plt.subplot(10, 10, i + 1)
        plt.imshow(weights[i].reshape(28, 28))
        #plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
nrOfNodes = 100

rbm = BernoulliRBM(n_components=nrOfNodes, learning_rate=0.01,n_iter=20,
                     batch_size=64, random_state=42,verbose=True)

# %%
history = rbm.fit(X_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -346.10, time = 0.74s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -243.79, time = 0.88s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -217.24, time = 0.82s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -196.75, time = 0.78s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -186.44, time = 0.87s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -177.33, time = 0.81s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -170.50, time = 0.84s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -164.46, time = 0.81s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -159.77, time = 0.80s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -156.95, time = 0.85s
# [BernoulliRBM] Iteration 11, pseudo-likelihood = -153.15, time = 0.86s
# [BernoulliRBM] Iteration 12, pseudo-likelihood = -150.24, time = 0.87s
# [BernoulliRBM] Iteration 13, pseudo-likelihood = -147.62, time = 0.87s
# [BernoulliRBM] Iteration 14, pseudo-likelihood = -145.69, time = 0.83s
# [BernoulliRBM] Iteration 15, pseudo-likelihood = -143.85, time = 0.84s
# [BernoulliRBM] Iteration 16, pseudo-likelihood = -142.02, time = 0.88s
# [BernoulliRBM] Iteration 17, pseudo-likelihood = -140.30, time = 0.86s
# [BernoulliRBM] Iteration 18, pseudo-likelihood = -138.66, time = 0.96s
# [BernoulliRBM] Iteration 19, pseudo-likelihood = -136.88, time = 0.91s
# [BernoulliRBM] Iteration 20, pseudo-likelihood = -135.17, time = 0.81s

# %%
weights = rbm.components_
weights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2289d114a16> in <module>()
# ----> 1 weights = rbm.components_
#       2 weights
#
# NameError: name 'rbm' is not defined

# %%
weights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fad624b28208> in <module>()
# ----> 1 weights
#
# NameError: name 'weights' is not defined

# %%
plotWeights(weights)

# %%
#Reconstruct digits from test data through gibbs sampling
pred = rbm.gibbs(X_test).astype(int)

# %%
plotImage(X_test[:10,:],pred[:10,:])

# %%
#Calculate mean squared error
mse = mean_squared_error(X_test,pred)
print(mse)
# Out:
# 0.11615369898
