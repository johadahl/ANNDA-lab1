# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.metrics import mean_squared_error

# %%
X_train = pd.read_csv("MNIST_data/bindigit_trn.csv",header=None).as_matrix()
y_train = pd.read_csv("MNIST_data/targetdigit_trn.csv",header=None,names=["Label"]).as_matrix()

X_test = pd.read_csv("MNIST_data/bindigit_tst.csv",header=None).as_matrix()
y_test = pd.read_csv("MNIST_data/targetdigit_tst.csv",header=None,names=["Label"]).as_matrix()

# %%
#train_digits

# %%
plt.hist(y_train)
plt.title("Distribution of labels")
plt.show()

# %%
y_train.shape
# Out:
# (8000, 1)

# %%
#Helper class for plotting images
def plotImage(images,predictions):
    n = 10  # how many digits we will display
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(images[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(predictions[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
def plotWeights(weights):
    n = weights.shape[0]  # how many digits we will display
    plt.figure(figsize=(20, 20))
    for i in range(n):
        # display weights
        ax = plt.subplot(10, 10, i + 1)
        plt.imshow(weights[i].reshape(28, 28))
        #plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %% [markdown]
# # Deep neural network architectures with restricted Boltzmann machines and autoencoders

# %% [markdown]
# ## Autoencoder

# %%
from keras.layers import Input, Dense
from keras.models import Model

# %%
# this is the size of our encoded representations
encoding_dim = 50  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder50 = Model(input_img, decoded)

# this model maps an input to its encoded representation
encoder50 = Model(input_img, encoded)

# %%
# this is the size of our encoded representations
encoding_dim = 75  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder75 = Model(input_img, decoded)

# %%
# this is the size of our encoded representations
encoding_dim = 100  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder100 = Model(input_img, decoded)

# this model maps an input to its encoded representation
encoder100 = Model(input_img, encoded)

# %%
# this is the size of our encoded representations
encoding_dim = 150  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder150 = Model(input_img, decoded)

# %%
'''
#Separate encoder model
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)
'''
# Out:
# '\n#Separate encoder model\n# this model maps an input to its encoded representation\nencoder = Model(input_img, encoded)\n'

# %%
'''

#Separate decoder model
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

'''
# Out:
# '\n\n#Separate decoder model\n# create a placeholder for an encoded (32-dimensional) input\nencoded_input = Input(shape=(encoding_dim,))\n# retrieve the last layer of the autoencoder model\ndecoder_layer = autoencoder.layers[-1]\n# create the decoder model\ndecoder = Model(encoded_input, decoder_layer(encoded_input))\n\n'

# %%
autoencoder50.compile(optimizer='adadelta', loss='mean_squared_error')
encoder50.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder75.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder100.compile(optimizer='adadelta', loss='mean_squared_error')
encoder100.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder150.compile(optimizer='adadelta', loss='mean_squared_error')

# %% [markdown]
# ## Training with 50 nodes, 200 epochs, batch size=32

# %%
history50 = autoencoder50.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 1s 158us/step - loss: 0.1726 - val_loss: 0.0980
# Epoch 2/50
# 8000/8000 [==============================] - 1s 117us/step - loss: 0.0927 - val_loss: 0.0900
# Epoch 3/50
# 8000/8000 [==============================] - 1s 130us/step - loss: 0.0893 - val_loss: 0.0882
# Epoch 4/50
# 8000/8000 [==============================] - 1s 130us/step - loss: 0.0878 - val_loss: 0.0868
# Epoch 5/50
# 8000/8000 [==============================] - 1s 113us/step - loss: 0.0864 - val_loss: 0.0852
# Epoch 6/50
# 8000/8000 [==============================] - 1s 125us/step - loss: 0.0846 - val_loss: 0.0831
# Epoch 7/50
# 8000/8000 [==============================] - 1s 118us/step - loss: 0.0824 - val_loss: 0.0806
# Epoch 8/50
# 8000/8000 [==============================] - 1s 127us/step - loss: 0.0798 - val_loss: 0.0779
# Epoch 9/50
# 8000/8000 [==============================] - 1s 113us/step - loss: 0.0770 - val_loss: 0.0751
# Epoch 10/50
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.0744 - val_loss: 0.0726
# Epoch 11/50
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.0720 - val_loss: 0.0704
# Epoch 12/50
# 8000/8000 [==============================] - 1s 114us/step - loss: 0.0699 - val_loss: 0.0684
# Epoch 13/50
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.0680 - val_loss: 0.0666
# Epoch 14/50
# 8000/8000 [==============================] - 1s 131us/step - loss: 0.0663 - val_loss: 0.0650
# Epoch 15/50
# 8000/8000 [==============================] - 1s 160us/step - loss: 0.0647 - val_loss: 0.0636
# Epoch 16/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.0633 - val_loss: 0.0622
# Epoch 17/50
# 8000/8000 [==============================] - 1s 122us/step - loss: 0.0620 - val_loss: 0.0610
# Epoch 18/50
# 8000/8000 [==============================] - 1s 124us/step - loss: 0.0608 - val_loss: 0.0598
# Epoch 19/50
# 8000/8000 [==============================] - 1s 125us/step - loss: 0.0596 - val_loss: 0.0588
# Epoch 20/50
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.0586 - val_loss: 0.0578
# Epoch 21/50
# 8000/8000 [==============================] - 1s 156us/step - loss: 0.0576 - val_loss: 0.0568
# Epoch 22/50
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.0567 - val_loss: 0.0559
# Epoch 23/50
# 8000/8000 [==============================] - 1s 116us/step - loss: 0.0558 - val_loss: 0.0551
# Epoch 24/50
# 8000/8000 [==============================] - 1s 116us/step - loss: 0.0550 - val_loss: 0.0543
# Epoch 25/50
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.0542 - val_loss: 0.0536
# Epoch 26/50
# 8000/8000 [==============================] - 1s 121us/step - loss: 0.0534 - val_loss: 0.0528
# Epoch 27/50
# 8000/8000 [==============================] - 1s 116us/step - loss: 0.0527 - val_loss: 0.0522
# Epoch 28/50
# 8000/8000 [==============================] - 1s 119us/step - loss: 0.0520 - val_loss: 0.0515
# Epoch 29/50
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.0513 - val_loss: 0.0509
# Epoch 30/50
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.0507 - val_loss: 0.0503
# Epoch 31/50
# 8000/8000 [==============================] - 1s 127us/step - loss: 0.0501 - val_loss: 0.0497
# Epoch 32/50
# 8000/8000 [==============================] - 1s 124us/step - loss: 0.0495 - val_loss: 0.0492
# Epoch 33/50
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.0490 - val_loss: 0.0486
# Epoch 34/50
# 8000/8000 [==============================] - 1s 124us/step - loss: 0.0484 - val_loss: 0.0481
# Epoch 35/50
# 8000/8000 [==============================] - 1s 119us/step - loss: 0.0479 - val_loss: 0.0476
# Epoch 36/50
# 8000/8000 [==============================] - 1s 127us/step - loss: 0.0474 - val_loss: 0.0471
# Epoch 37/50
# 8000/8000 [==============================] - 1s 117us/step - loss: 0.0469 - val_loss: 0.0467
# Epoch 38/50
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.0464 - val_loss: 0.0462
# Epoch 39/50
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.0459 - val_loss: 0.0458
# Epoch 40/50
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.0455 - val_loss: 0.0454
# Epoch 41/50
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.0451 - val_loss: 0.0449
# Epoch 42/50
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.0446 - val_loss: 0.0445
# Epoch 43/50
#  - ETA: 1s - loss: 0.0442
# Epoch 44/50
# 8000/8000 [==============================] - 1s 127us/step - loss: 0.0438 - val_loss: 0.0437
# Epoch 45/50
# 8000/8000 [==============================] - 1s 114us/step - loss: 0.0434 - val_loss: 0.0434
# Epoch 46/50
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.0430 - val_loss: 0.0430
# Epoch 47/50
# 8000/8000 [==============================] - 1s 121us/step - loss: 0.0426 - val_loss: 0.0426
# Epoch 48/50
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.0422 - val_loss: 0.0423
# Epoch 49/50
# 8000/8000 [==============================] - 1s 118us/step - loss: 0.0419 - val_loss: 0.0419
# Epoch 50/50
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.0415 - val_loss: 0.0416

# %%
history75 = autoencoder75.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.1806 - val_loss: 0.0989
# Epoch 2/50
# 8000/8000 [==============================] - 1s 119us/step - loss: 0.0926 - val_loss: 0.0894
# Epoch 3/50
# 8000/8000 [==============================] - 1s 120us/step - loss: 0.0886 - val_loss: 0.0871
# Epoch 4/50
# 8000/8000 [==============================] - 1s 122us/step - loss: 0.0865 - val_loss: 0.0851
# Epoch 5/50
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.0844 - val_loss: 0.0828
# Epoch 6/50
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.0819 - val_loss: 0.0801
# Epoch 7/50
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.0791 - val_loss: 0.0772
# Epoch 8/50
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.0763 - val_loss: 0.0743
# Epoch 9/50
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.0735 - val_loss: 0.0717
# Epoch 10/50
# 8000/8000 [==============================] - 1s 130us/step - loss: 0.0710 - val_loss: 0.0693
# Epoch 11/50
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.0688 - val_loss: 0.0672
# Epoch 12/50
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.0667 - val_loss: 0.0653
# Epoch 13/50
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.0649 - val_loss: 0.0636
# Epoch 14/50
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.0633 - val_loss: 0.0621
# Epoch 15/50
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.0618 - val_loss: 0.0607
# Epoch 16/50
# 8000/8000 [==============================] - 1s 124us/step - loss: 0.0604 - val_loss: 0.0594
# Epoch 17/50
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.0592 - val_loss: 0.0583
# Epoch 18/50
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.0580 - val_loss: 0.0572
# Epoch 19/50
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.0569 - val_loss: 0.0562
# Epoch 20/50
# 8000/8000 [==============================] - 1s 148us/step - loss: 0.0559 - val_loss: 0.0552
# Epoch 21/50
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.0550 - val_loss: 0.0543
# Epoch 22/50
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.0541 - val_loss: 0.0535
# Epoch 23/50
# 8000/8000 [==============================] - 1s 131us/step - loss: 0.0533 - val_loss: 0.0527
# Epoch 24/50
# 8000/8000 [==============================] - 1s 148us/step - loss: 0.0525 - val_loss: 0.0520
# Epoch 25/50
# 8000/8000 [==============================] - 1s 124us/step - loss: 0.0517 - val_loss: 0.0513
# Epoch 26/50
# 8000/8000 [==============================] - 1s 131us/step - loss: 0.0510 - val_loss: 0.0506
# Epoch 27/50
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.0503 - val_loss: 0.0499
# Epoch 28/50
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.0496 - val_loss: 0.0493
# Epoch 29/50
# 8000/8000 [==============================] - 1s 131us/step - loss: 0.0490 - val_loss: 0.0487
# Epoch 30/50
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.0483 - val_loss: 0.0481
# Epoch 31/50
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.0478 - val_loss: 0.0475
# Epoch 32/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.0472 - val_loss: 0.0470
# Epoch 33/50
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.0466 - val_loss: 0.0465
# Epoch 34/50
# 8000/8000 [==============================] - 1s 122us/step - loss: 0.0461 - val_loss: 0.0459
# Epoch 35/50
# 8000/8000 [==============================] - 1s 155us/step - loss: 0.0455 - val_loss: 0.0454
# Epoch 36/50
# 8000/8000 [==============================] - 1s 163us/step - loss: 0.0450 - val_loss: 0.0449
# Epoch 37/50
# 8000/8000 [==============================] - 1s 130us/step - loss: 0.0445 - val_loss: 0.0445
# Epoch 38/50
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.0441 - val_loss: 0.0440
# Epoch 39/50
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.0436 - val_loss: 0.0436
# Epoch 40/50
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.0431 - val_loss: 0.0431
# Epoch 41/50
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.0427 - val_loss: 0.0427
# Epoch 42/50
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.0422 - val_loss: 0.0423
# Epoch 43/50
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.0418 - val_loss: 0.0419
# Epoch 44/50
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.0414 - val_loss: 0.0415
# Epoch 45/50
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.0410 - val_loss: 0.0411
# Epoch 46/50
#  - ETA: 1s - loss: 0.0410
# Epoch 47/50
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.0402 - val_loss: 0.0403
# Epoch 48/50
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.0398 - val_loss: 0.0400
# Epoch 49/50
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.0395 - val_loss: 0.0396
# Epoch 50/50
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.0391 - val_loss: 0.0393

# %%
history100 = autoencoder100.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 1s 182us/step - loss: 0.1727 - val_loss: 0.0968
# Epoch 2/50
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.0916 - val_loss: 0.0887
# Epoch 3/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.0877 - val_loss: 0.0861
# Epoch 4/50
# 8000/8000 [==============================] - 1s 158us/step - loss: 0.0853 - val_loss: 0.0837
# Epoch 5/50
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.0827 - val_loss: 0.0809
# Epoch 6/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.0798 - val_loss: 0.0778
# Epoch 7/50
# 8000/8000 [==============================] - 1s 155us/step - loss: 0.0767 - val_loss: 0.0747
# Epoch 8/50
# 8000/8000 [==============================] - 1s 164us/step - loss: 0.0737 - val_loss: 0.0718
# Epoch 9/50
# 8000/8000 [==============================] - 1s 170us/step - loss: 0.0710 - val_loss: 0.0692
# Epoch 10/50
# 8000/8000 [==============================] - 1s 179us/step - loss: 0.0685 - val_loss: 0.0670
# Epoch 11/50
# 8000/8000 [==============================] - 1s 169us/step - loss: 0.0664 - val_loss: 0.0649
# Epoch 12/50
# 8000/8000 [==============================] - 1s 153us/step - loss: 0.0644 - val_loss: 0.0631
# Epoch 13/50
# 8000/8000 [==============================] - 1s 167us/step - loss: 0.0627 - val_loss: 0.0615
# Epoch 14/50
# 8000/8000 [==============================] - 1s 168us/step - loss: 0.0611 - val_loss: 0.0600
# Epoch 15/50
# 8000/8000 [==============================] - 1s 160us/step - loss: 0.0596 - val_loss: 0.0587
# Epoch 16/50
# 8000/8000 [==============================] - 1s 170us/step - loss: 0.0583 - val_loss: 0.0574
# Epoch 17/50
# 8000/8000 [==============================] - 1s 164us/step - loss: 0.0571 - val_loss: 0.0563
# Epoch 18/50
# 8000/8000 [==============================] - 1s 173us/step - loss: 0.0559 - val_loss: 0.0552
# Epoch 19/50
# 8000/8000 [==============================] - 1s 171us/step - loss: 0.0549 - val_loss: 0.0542
# Epoch 20/50
# 8000/8000 [==============================] - 1s 162us/step - loss: 0.0538 - val_loss: 0.0532
# Epoch 21/50
# 8000/8000 [==============================] - 1s 159us/step - loss: 0.0529 - val_loss: 0.0523
# Epoch 22/50
# 8000/8000 [==============================] - 1s 163us/step - loss: 0.0520 - val_loss: 0.0515
# Epoch 23/50
# 8000/8000 [==============================] - 1s 171us/step - loss: 0.0511 - val_loss: 0.0507
# Epoch 24/50
# 8000/8000 [==============================] - 1s 166us/step - loss: 0.0503 - val_loss: 0.0499
# Epoch 25/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.0495 - val_loss: 0.0492
# Epoch 26/50
# 8000/8000 [==============================] - 1s 168us/step - loss: 0.0487 - val_loss: 0.0485
# Epoch 27/50
# 8000/8000 [==============================] - 1s 165us/step - loss: 0.0480 - val_loss: 0.0478
# Epoch 28/50
# 8000/8000 [==============================] - 1s 163us/step - loss: 0.0473 - val_loss: 0.0471
# Epoch 29/50
# 8000/8000 [==============================] - 1s 157us/step - loss: 0.0467 - val_loss: 0.0465
# Epoch 30/50
# 8000/8000 [==============================] - 1s 172us/step - loss: 0.0460 - val_loss: 0.0459
# Epoch 31/50
# 8000/8000 [==============================] - 1s 167us/step - loss: 0.0454 - val_loss: 0.0453
# Epoch 32/50
# 8000/8000 [==============================] - 1s 155us/step - loss: 0.0448 - val_loss: 0.0448
# Epoch 33/50
# 8000/8000 [==============================] - 1s 176us/step - loss: 0.0443 - val_loss: 0.0442
# Epoch 34/50
# 8000/8000 [==============================] - 2s 204us/step - loss: 0.0437 - val_loss: 0.0437
# Epoch 35/50
# 8000/8000 [==============================] - 1s 173us/step - loss: 0.0432 - val_loss: 0.0432
# Epoch 36/50
# 8000/8000 [==============================] - 1s 173us/step - loss: 0.0427 - val_loss: 0.0427
# Epoch 37/50
# 8000/8000 [==============================] - 1s 157us/step - loss: 0.0421 - val_loss: 0.0422
# Epoch 38/50
# 8000/8000 [==============================] - 1s 167us/step - loss: 0.0417 - val_loss: 0.0418
# Epoch 39/50
# 8000/8000 [==============================] - 1s 156us/step - loss: 0.0412 - val_loss: 0.0413
# Epoch 40/50
# 8000/8000 [==============================] - 1s 162us/step - loss: 0.0407 - val_loss: 0.0409
# Epoch 41/50
# 8000/8000 [==============================] - 1s 177us/step - loss: 0.0403 - val_loss: 0.0404
# Epoch 42/50
# 8000/8000 [==============================] - 1s 154us/step - loss: 0.0399 - val_loss: 0.0400
# Epoch 43/50
# 8000/8000 [==============================] - 1s 156us/step - loss: 0.0394 - val_loss: 0.0396
# Epoch 44/50
# 8000/8000 [==============================] - 1s 165us/step - loss: 0.0390 - val_loss: 0.0392
# Epoch 45/50
# 8000/8000 [==============================] - 2s 192us/step - loss: 0.0386 - val_loss: 0.0388
# Epoch 46/50
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.0383 - val_loss: 0.0385
# Epoch 47/50
# 8000/8000 [==============================] - 1s 165us/step - loss: 0.0379 - val_loss: 0.0381
# Epoch 48/50
# 8000/8000 [==============================] - 1s 181us/step - loss: 0.0375 - val_loss: 0.0378
# Epoch 49/50
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.0371 - val_loss: 0.0374
# Epoch 50/50
# 8000/8000 [==============================] - 1s 165us/step - loss: 0.0368 - val_loss: 0.0371

# %%
history150 = autoencoder150.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 2s 223us/step - loss: 0.1589 - val_loss: 0.0948
# Epoch 2/50
# 8000/8000 [==============================] - 1s 182us/step - loss: 0.0909 - val_loss: 0.0882
# Epoch 3/50
# 8000/8000 [==============================] - 3s 332us/step - loss: 0.0871 - val_loss: 0.0854
# Epoch 4/50
# 8000/8000 [==============================] - 2s 273us/step - loss: 0.0844 - val_loss: 0.0826
# Epoch 5/50
# 8000/8000 [==============================] - 2s 191us/step - loss: 0.0814 - val_loss: 0.0794
# Epoch 6/50
# 8000/8000 [==============================] - 1s 162us/step - loss: 0.0782 - val_loss: 0.0760
# Epoch 7/50
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.0749 - val_loss: 0.0728
# Epoch 8/50
# 8000/8000 [==============================] - 1s 180us/step - loss: 0.0718 - val_loss: 0.0699
# Epoch 9/50
# 8000/8000 [==============================] - 1s 182us/step - loss: 0.0691 - val_loss: 0.0674
# Epoch 10/50
# 8000/8000 [==============================] - 2s 190us/step - loss: 0.0667 - val_loss: 0.0652
# Epoch 11/50
# 8000/8000 [==============================] - 1s 170us/step - loss: 0.0646 - val_loss: 0.0632
# Epoch 12/50
# 8000/8000 [==============================] - 1s 159us/step - loss: 0.0627 - val_loss: 0.0614
# Epoch 13/50
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.0609 - val_loss: 0.0598
# Epoch 14/50
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.0594 - val_loss: 0.0583
# Epoch 15/50
# 8000/8000 [==============================] - 1s 184us/step - loss: 0.0579 - val_loss: 0.0570
# Epoch 16/50
# 8000/8000 [==============================] - 1s 183us/step - loss: 0.0566 - val_loss: 0.0557
# Epoch 17/50
# 8000/8000 [==============================] - 1s 175us/step - loss: 0.0553 - val_loss: 0.0545
# Epoch 18/50
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.0542 - val_loss: 0.0535
# Epoch 19/50
# 8000/8000 [==============================] - 1s 177us/step - loss: 0.0531 - val_loss: 0.0525
# Epoch 20/50
# 8000/8000 [==============================] - 2s 190us/step - loss: 0.0521 - val_loss: 0.0515
# Epoch 21/50
# 8000/8000 [==============================] - 2s 192us/step - loss: 0.0511 - val_loss: 0.0506
# Epoch 22/50
# 8000/8000 [==============================] - 1s 148us/step - loss: 0.0502 - val_loss: 0.0497
# Epoch 23/50
# 8000/8000 [==============================] - 2s 188us/step - loss: 0.0494 - val_loss: 0.0489
# Epoch 24/50
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.0485 - val_loss: 0.0482
# Epoch 25/50
# 8000/8000 [==============================] - 1s 180us/step - loss: 0.0478 - val_loss: 0.0474
# Epoch 26/50
# 8000/8000 [==============================] - 1s 178us/step - loss: 0.0470 - val_loss: 0.0467
# Epoch 27/50
# 8000/8000 [==============================] - 1s 185us/step - loss: 0.0463 - val_loss: 0.0460
# Epoch 28/50
# 8000/8000 [==============================] - 1s 179us/step - loss: 0.0456 - val_loss: 0.0454
# Epoch 29/50
# 8000/8000 [==============================] - 2s 193us/step - loss: 0.0450 - val_loss: 0.0448
# Epoch 30/50
# 8000/8000 [==============================] - 1s 180us/step - loss: 0.0443 - val_loss: 0.0442
# Epoch 31/50
# 8000/8000 [==============================] - 1s 174us/step - loss: 0.0437 - val_loss: 0.0436
# Epoch 32/50
# 8000/8000 [==============================] - 1s 180us/step - loss: 0.0431 - val_loss: 0.0430
# Epoch 33/50
# 8000/8000 [==============================] - 2s 188us/step - loss: 0.0425 - val_loss: 0.0425
# Epoch 34/50
# 8000/8000 [==============================] - 2s 188us/step - loss: 0.0420 - val_loss: 0.0419
# Epoch 35/50
# 8000/8000 [==============================] - 1s 182us/step - loss: 0.0414 - val_loss: 0.0414
# Epoch 36/50
# 8000/8000 [==============================] - 1s 178us/step - loss: 0.0409 - val_loss: 0.0409
# Epoch 37/50
#  - ETA: 1s - loss: 0.0405
# Epoch 38/50
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.0399 - val_loss: 0.0400
# Epoch 39/50
# 8000/8000 [==============================] - 1s 184us/step - loss: 0.0394 - val_loss: 0.0395
# Epoch 40/50
# 8000/8000 [==============================] - 1s 184us/step - loss: 0.0390 - val_loss: 0.0391
# Epoch 41/50
# 8000/8000 [==============================] - 1s 184us/step - loss: 0.0385 - val_loss: 0.0386
# Epoch 42/50
# 8000/8000 [==============================] - 1s 183us/step - loss: 0.0381 - val_loss: 0.0382
# Epoch 43/50
# 8000/8000 [==============================] - 2s 188us/step - loss: 0.0377 - val_loss: 0.0378
# Epoch 44/50
# 8000/8000 [==============================] - 1s 184us/step - loss: 0.0372 - val_loss: 0.0374
# Epoch 45/50
# 8000/8000 [==============================] - 1s 164us/step - loss: 0.0368 - val_loss: 0.0370
# Epoch 46/50
# 8000/8000 [==============================] - 2s 191us/step - loss: 0.0364 - val_loss: 0.0366
# Epoch 47/50
# 8000/8000 [==============================] - 1s 169us/step - loss: 0.0360 - val_loss: 0.0363
# Epoch 48/50
# 8000/8000 [==============================] - 1s 174us/step - loss: 0.0357 - val_loss: 0.0359
# Epoch 49/50
# 8000/8000 [==============================] - 2s 189us/step - loss: 0.0353 - val_loss: 0.0355
# Epoch 50/50
# 8000/8000 [==============================] - 1s 175us/step - loss: 0.0349 - val_loss: 0.0352

# %%
loss = history50.history['loss']
valLoss = history50.history['val_loss']
plt.plot(range(len(loss)),loss,color='b',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='orange',label='Test error')
plt.title('Loss against epochs')
plt.legend()
plt.show()

# %%
loss = history75.history['loss']
valLoss = history75.history['val_loss']
plt.plot(range(len(loss)),loss,color='b',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='orange',label='Test error')
plt.title('Loss against epochs')
plt.legend()
plt.show()

# %%
loss = history100.history['loss']
valLoss = history100.history['val_loss']
plt.plot(range(len(loss)),loss,color='b',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='orange',label='Test error')
plt.title('Loss against epochs')
plt.legend()
plt.show()

# %%
loss = history150.history['loss']
valLoss = history150.history['val_loss']
plt.plot(range(len(loss)),loss,color='b',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='orange',label='Test error')
plt.title('Loss against epochs')
plt.legend()
plt.show()

# %%
# encode and decode some digits
# note that we take them from the *test* set
#encoded_imgs = encoder.predict(X_test)
#decoded_imgs = decoder.predict(encoded_imgs)

pred50 = autoencoder50.predict(X_test)
pred75 = autoencoder75.predict(X_test)
pred100 = autoencoder100.predict(X_test)
pred150 = autoencoder150.predict(X_test)
#a50 = autoencoder.predict(X_test[:10,:])
#a150 = autoencoder.predict(X_test[:10,:])

# %% [markdown]
# ## ?????

# %%
#DON'T TOUCH
#sampleDigits = [X_test[26],X_test[3],X_test[7],X_test[0],X_test[2],
#               X_test[1],X_test[15],X_test[8],X_test[6],X_test[5]]


#samplePredictions = [decoded_imgs[26],decoded_imgs[3],decoded_imgs[7],decoded_imgs[0],decoded_imgs[2],
#               decoded_imgs[1],decoded_imgs[15],decoded_imgs[8],decoded_imgs[6],decoded_imgs[5]]

#plotImage(X_test[:10,:],a)

# %% [markdown]
# ## Printed digits for all predictions

# %%
plotImage(X_test[:10,:],pred50)

# %%
plotImage(X_test[:10,:],pred75)

# %%
plotImage(X_test[:10,:],pred100)

# %%
plotImage(X_test[:10,:],pred150)

# %%
#apa = encoder.get_weights()
#plotImage(apa[0].T[:10,:],apa[0].T[10:20,:])

# %%
#Calculate mean squared error
mse50 = mean_squared_error(X_test,pred50)
mse75 = mean_squared_error(X_test,pred75)
mse100 = mean_squared_error(X_test,pred100)
mse150 = mean_squared_error(X_test,pred150)
print(mse50)
print(mse75)
print(mse100)
print(mse150)
# Out:
# 0.0414740007542
# 0.0394403994281
# 0.0381759575788
# 0.0350180358063

# %%
weights50 = autoencoder50.get_weights()[0].T
weights100 = autoencoder100.get_weights()[0].T

# %%
plotWeights(weights50)

# %%
plotWeights(weights100)
